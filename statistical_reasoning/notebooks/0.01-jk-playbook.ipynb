# %%
# Add this in each notebook!
import sys
sys.path.append('../src')  # Add the src directory to the system path

# %%
# Import dependencies/modules
import pandas as pd

# %%
# Get dataframe
df = pd.read_csv('../data/raw/employee_data.csv')
df.head()
# Out:
#        Name     Salary         DOJ  Age  Gender  Dependents        HA  \
# 0  ZuLzMAsP   88438.99  10/25/2019   36  Female           2  7142.101
# 1  xQYGOrHv  137819.29   11/8/2020   57  Female           4  4660.071
# 2  jehfxCGw   81316.12   1/20/2014   37    Male           3  5485.388
# 3  yCezYiFJ  111420.62   2/13/2012   55  Female           1  7822.938
# 4  WDQboEZv   16185.35    5/4/2020   24   Other           2  8137.465
#
#            COLA           CPF   Gross Salary Insurance Marital Status  \
# 0  20872.462360  13117.374283  103336.179077   Medical        Married
# 1  32526.693747  20441.518050  154564.536697   Medical        Married
# 2  19191.395718  12060.901886   93932.001832       NaN       Divorced
# 3  26296.350706  16526.036485  129013.872221      Life       Divorced
# 4   3819.900122   2400.630015   25742.085107   Medical        Married
#
#    In Company Years  Year of Experience Department                    Position
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                4600 non-null   object
#  1   Salary              4600 non-null   float64
#  2   DOJ                 4600 non-null   object
#  3   Age                 4600 non-null   int64
#  4   Gender              4600 non-null   object
#  5   Dependents          4600 non-null   int64
#  6   HA                  4600 non-null   float64
#  7   COLA                4600 non-null   float64
#  8   CPF                 4600 non-null   float64
#  9   Gross Salary        4600 non-null   float64
#  10  Insurance           3464 non-null   object
#  11  Marital Status      4600 non-null   object
#  12  In Company Years    4600 non-null   int64
#  13  Year of Experience  4600 non-null   int64
#  14  Department          4600 non-null   object
# ...

# %%
df.describe().transpose()
# Out:
#                      count           mean           std           min  \
# Salary              4600.0   94292.524720  33983.208928  15042.700000
# Age                 4600.0      40.386739     11.360860     21.000000
# Dependents          4600.0       1.960000      1.298521      0.000000
# HA                  4600.0    7999.620354   2330.275836   3127.273000
# COLA                4600.0   22253.953523   8020.368044   3550.223601
# CPF                 4600.0   13985.577389   5040.429237   2231.150832
# Gross Salary        4600.0  110560.521207  37523.647811  22624.827875
# In Company Years    4600.0       9.936522      8.818178      0.000000
# Year of Experience  4600.0      19.386739     11.360860      0.000000
#
#                              25%            50%            75%            max
# Salary              70548.410000   96732.995000  122100.132500  149991.340000
# Age                    30.000000      40.000000      50.250000      60.000000
# ...

# %%
# Advanced .describe() - Descriptive Statistics
from descriptive_statistics import advanced_describe
advanced_describe(df)
# Out:
#                      count           mean           std           min  \
# Variable
# Salary              4600.0   94292.524720  33983.208928  15042.700000
# Age                 4600.0      40.386739     11.360860     21.000000
# Dependents          4600.0       1.960000      1.298521      0.000000
# HA                  4600.0    7999.620354   2330.275836   3127.273000
# COLA                4600.0   22253.953523   8020.368044   3550.223601
# CPF                 4600.0   13985.577389   5040.429237   2231.150832
# Gross Salary        4600.0  110560.521207  37523.647811  22624.827875
# In Company Years    4600.0       9.936522      8.818178      0.000000
# Year of Experience  4600.0      19.386739     11.360860      0.000000
#
#                              25%            50%            75%            max  \
# Variable
# Salary              70548.410000   96732.995000  122100.132500  149991.340000
# Age                    30.000000      40.000000      50.250000      60.000000
# ...

# %% [markdown]
# ![Alt text](../images/data_dict.png)

# %% [markdown]
# ## Descriptive Statistics
# **Findings:**
# - Averages/Mean: *The mean age, years of experience & years in company are relatively high, indicating "maturity". Might be good to consider median as well.*
# - Distribution of compensations like COLA & CPF models closely to salary (left skewed), indicating employee compensation matches closely to experience/age? However, distribution of housing allowance (HA) is right skewed, perhaps needing some reviews.
# - Marital Status: Most employees (close to 3000/4600) are married, emphasising importance of family benefits.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from descriptive_statistics import plot_descriptive_stats
# Out:
# 2024-09-15 09:08:43,790 - config - INFO - PROJ_ROOT path is: /Users/jinkettyee/Desktop/PycharmProjects/statistical_reasoning
# 2024-09-15 09:08:43,795 - config - INFO - TQDM logging setup complete.
# 2024-09-15 09:08:43,795 - config - INFO - TQDM logging setup complete.

# %%
plot_descriptive_stats()
# Out:
# /Users/jinkettyee/Desktop/PycharmProjects/statistical_reasoning/notebooks/../src/descriptive_statistics.py:36: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette='Set2')
# /Users/jinkettyee/Desktop/PycharmProjects/statistical_reasoning/notebooks/../src/descriptive_statistics.py:36: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette='Set2')
# /Users/jinkettyee/Desktop/PycharmProjects/statistical_reasoning/notebooks/../src/descriptive_statistics.py:36: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...
